# %%
from model.origin_SalientSleepNet import TinySalientSleepNet

net = TinySalientSleepNet(2,5,5, [16, 32, 32, 64, 128], [10, 5, 5, 5], 1, 30 * 100,
                                120, 5, [16, 16, 32, 64, 128]).cuda()
# Out:
# /data/ZhangShaoqi/miniconda3/lib/python3.7/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484809535/work/aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
# 保存完整模型
import torch
net = torch.load('./result/IIMS_len120/fold0_model.pkl')

torch.save(net, 'model.pth')

# %%
# 读取完整模型
net = torch.load('model.pth')

# %%
# 用torch.jit.script来保存模型
import torch
from model.origin_SalientSleepNet import TinySalientSleepNet

net = TinySalientSleepNet(5, [16, 32, 32, 64, 128], [10, 5, 5, 5], 1, 30 * 100,
                                120, 5, [16, 16, 32, 64, 128]).cuda()
net.load_state_dict(torch.load('./result/IIMS_len120/TinySalientSleepNet.pth'))
net = torch.jit.script(net)
torch.jit.save(net, 'model_script.pt')
# 读取脚本模型
import torch
net = torch.jit.load('model_script.pt')
# Out:
# /data/ZhangShaoqi/miniconda3/lib/python3.7/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484809535/work/aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_31569/2400557201.py in <module>
#       6                                 120, 5, [16, 16, 32, 64, 128]).cuda()
#       7 net.load_state_dict(torch.load('./result/IIMS_len120/TinySalientSleepNet.pth'))
# ----> 8 net = torch.jit.script(net)
#       9 torch.jit.save(net, 'model_script.pt')
#      10 # 读取脚本模型
#
# ~/miniconda3/lib/python3.7/site-packages/torch/jit/_script.py in script(obj, optimize, _frames_up, _rcb, example_inputs)
# ...
